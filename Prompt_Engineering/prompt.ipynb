# %%
# !pip install gpt4all
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for gpt4all from https://files.pythonhosted.org/packages/04/92/dd9dd077f0fc61218e4116a7154958eff36f06893506ad3290802218b1c9/gpt4all-2.8.2-py3-none-win_amd64.whl.metadata
#   Using cached gpt4all-2.8.2-py3-none-win_amd64.whl.metadata (4.8 kB)
# ...
#    ---------------------------------------- 0.0/119.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/119.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/119.6 MB 871.5 kB/s eta 0:02:18
#    ---------------------------------------- 0.1/119.6 MB 787.7 kB/s eta 0:02:32
#    ---------------------------------------- 0.1/119.6 MB 655.4 kB/s eta 0:03:03
#    ---------------------------------------- 0.1/119.6 MB 535.8 kB/s eta 0:03:44
#    ---------------------------------------- 0.1/119.6 MB 462.0 kB/s eta 0:04:19
#    ---------------------------------------- 0.1/119.6 MB 462.0 kB/s eta 0:04:19
# ...

# %%
from gpt4all import GPT4All
# Out:
# Downloading: 100%|██████████| 1.98G/1.98G [04:51<00:00, 6.78MiB/s]
# Verifying: 100%|██████████| 1.98G/1.98G [00:09<00:00, 200MiB/s]
# 2,1

# %%
# Function to generate a response based on an instruction and a paragraph
def generate_response(instruction, paragraph):
    # Combine the instruction and paragraph into a single input
    combined_input = f"{instruction}\n\n{paragraph}"
    
    # Generate a response using the model
    response = model.generate(combined_input)
    
    return response

instruction = "give me two python question"
paragraph = "python"

output = generate_response(instruction, paragraph)
print(output)
# Out:
#  code to calculate the average of a list of numbers.
#
# And secondly, how can I create a function that takes in a list of integers and returns the sum of all the integers?

# %%
instruction = "HI hello, very good morning"
paragraph = "Translate to spanish language"

output = generate_response(instruction, paragraph)
print(output)
# Out:
# : "Hello, how are you?"
#
# Spanish translation: ¡Hola, cómo estás?

# %%
instruction = "yellow"
paragraph = "Give the RGB number"

output = generate_response(instruction, paragraph)
print(output)
# Out:
#  values for this color.
